# %%
import pandas as pd

# %%
df = pd.read_csv(r'../input/Raw Data.csv')

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 1. Age
# 18-22       1273
# 23-26        673
# 27-30         24
# Below 18       4
# Above 30       3
# Name: count, dtype: int64
# 2. Gender
# Male                 1372
# Female                595
# Prefer not to say      10
# Name: count, dtype: int64
# 3. University
# Independent University, Bangladesh (IUB)                      584
# American International University Bangladesh (AIUB)           529
# Islamic University of Technology (IUT)                        278
# Dhaka University (DU)                                         202
# Dhaka University of Engineering and Technology (DUET)         164
# North South University (NSU)                                   91
# Patuakhali Science and Technology University                   36
# Bangladesh University of Engineering and Technology (BUET)     32
# East West University (EWU)                                     19
# Rajshahi University of Engineering and Technology (RUET)       13
# ...

# %%
new_column_names = {
    '1. Age': 'Age',
    '2. Gender': 'Gender',
    '3. University': 'University',
    '4. Department': 'Department',
    '5. Academic Year': 'Academic_Year',
    '6. Current CGPA': 'CGPA',
    'Scholarship': 'Scholarship',
    '1. In a semester, how often you felt nervous, anxious or on edge due to academic pressure? ': 'Nervous_Anxiou',
       '2. In a semester, how often have you been unable to stop worrying about your academic affairs? ': 'Worrying',
       '3. In a semester, how often have you had trouble relaxing due to academic pressure? ': 'Trouble_Relaxing',
       '4. In a semester, how often have you been easily annoyed or irritated because of academic pressure?': 'Easily_Annoyed',
       '5. In a semester, how often have you worried too much about academic affairs? ': 'Worried_About_Affairs',
       '6. In a semester, how often have you been so restless due to academic pressure that it is hard to sit still?': 'Restless',
       '7. In a semester, how often have you felt afraid, as if something awful might happen?': 'Felt_Afraid',
       'Anxiety Value': 'Anxiety_Value',
       'Anxiety Label': 'Anxiety_Label',
       '1. In a semester, how often have you felt upset due to something that happened in your academic affairs? ': 'Felt_Upset',
       '2. In a semester, how often you felt as if you were unable to control important things in your academic affairs?': 'Unable_to_Control',
       '3. In a semester, how often you felt nervous and stressed because of academic pressure? ': 'Nervous_and_Stressed',
       '4. In a semester, how often you felt as if you could not cope with all the mandatory academic activities? (e.g, assignments, quiz, exams) ': 'Unable_to_Cope',
       '5. In a semester, how often you felt confident about your ability to handle your academic / university problems?': 'Confident',
       '6. In a semester, how often you felt as if things in your academic life is going on your way? ': 'Going_Your_Way',
       '7. In a semester, how often are you able to control irritations in your academic / university affairs? ': 'Control_Irritations',
       '8. In a semester, how often you felt as if your academic performance was on top?': 'On_Top_Performance',
       '9. In a semester, how often you got angered due to bad performance or low grades that is beyond your control? ': 'Angered',
       '10. In a semester, how often you felt as if academic difficulties are piling up so high that you could not overcome them? ': 'Piling_Up',
       'Stress Value': 'Stress_Value', 'Stress Label': 'Stress_Label',
       '1. In a semester, how often have you had little interest or pleasure in doing things?': 'Little_Interest',
       '2. In a semester, how often have you been feeling down, depressed or hopeless?': 'Feeling_Down',
       '3. In a semester, how often have you had trouble falling or staying asleep, or sleeping too much? ': 'Trouble_Sleeping',
       '4. In a semester, how often have you been feeling tired or having little energy? ': 'Tired_or_Little_Energy',
       '5. In a semester, how often have you had poor appetite or overeating? ': 'Poor_Appetite',
       '6. In a semester, how often have you been feeling bad about yourself - or that you are a failure or have let yourself or your family down? ': 'Feeling_Bad',
       '7. In a semester, how often have you been having trouble concentrating on things, such as reading the books or watching television? ': 'Trouble_Concentrating',
       "8. In a semester, how often have you moved or spoke too slowly for other people to notice? Or you've been moving a lot more than usual because you've been restless? " : 'Moving_or_Speaking_Too_Slowly',
       '9. In a semester, how often have you had thoughts that you would be better off dead, or of hurting yourself? ': 'Hurt_Yourself',
       'Depression Value': 'Depression_Value', 'Depression Label': 'Depression_Label'}

df.rename(columns=new_column_names, inplace=True)
df.dropna(how='any')
# Out:
#         Age  Gender                                University  \
# 0     18-22  Female  Independent University, Bangladesh (IUB)
# 1     18-22    Male  Independent University, Bangladesh (IUB)
# 2     18-22    Male  Independent University, Bangladesh (IUB)
# 3     18-22    Male  Independent University, Bangladesh (IUB)
# 4     18-22    Male  Independent University, Bangladesh (IUB)
# ...     ...     ...                                       ...
# 1972  23-26    Male  Bangladesh Agricultural University (BAU)
# 1973  23-26  Female  Bangladesh Agricultural University (BAU)
# 1974  23-26  Female  Bangladesh Agricultural University (BAU)
# 1975  23-26    Male  Bangladesh Agricultural University (BAU)
# 1976  23-26    Male  Independent University, Bangladesh (IUB)
#
#                                         Department              Academic_Year  \
# 0     Engineering - CS / CSE / CSC / Similar to CS  Fourth Year or Equivalent
# ...

# %%
dept_rename = {
    'Engineering - CS / CSE / CSC / Similar to CS': 'Engineering', 'Other': 'Other',
       'Engineering - EEE/ ECE / Similar to EEE': 'Engineering',
       'Environmental and Life Sciences': 'Environmental and Life Sciences',
       'Business and Entrepreneurship Studies': 'Business and Entrepreneurship Studies',
       'Pharmacy and Public Health': 'Other', 'Biological Sciences': 'Biological Sciences',
       'Engineering - Civil Engineering / Similar to CE': 'Engineering',
       'Engineering - Mechanical Engineering / Similar to ME': 'Engineering',
       'Engineering - Other': 'Engineering', 'Law and Human Rights': 'Other',
       'Liberal Arts and Social Sciences': 'Other'}

df['Department'] = df['Department'].map(dept_rename)
df['Department'].value_counts()
# Out:
# Department
# Engineering                              1626
# Business and Entrepreneurship Studies     129
# Biological Sciences                        95
# Other                                      80
# Environmental and Life Sciences            47
# Name: count, dtype: int64

# %%
ac_yr_rename = {
    'First Year or Equivalent': 1,
    'Second Year or Equivalent': 2,
    'Third Year or Equivalent': 3,
    'Fourth Year or Equivalent': 4,
    'Other': -1
}

df['Academic_Year'] = df['Academic_Year'].map(ac_yr_rename)
df['Academic_Year'].value_counts()
# Out:
# Academic_Year
#  1.0    592
#  3.0    552
#  4.0    392
#  2.0    370
# -1.0     71
# Name: count, dtype: int64

# %%
cgpa_rename = {
    '3.00 - 3.39': 3,
    '3.40 - 3.79': 4,
    '2.50 - 2.99': 2,
    '3.80 - 4.00': 5,
    'Other': 0,
    'Below 2.50': 1
}

df['CGPA'] = df['CGPA'].map(cgpa_rename)
df['CGPA'].value_counts()
# Out:
# CGPA
# 3.0    572
# 4.0    551
# 2.0    368
# 5.0    237
# 0.0    168
# 1.0     81
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.dropna(how='any', inplace=True)

# %%
numerical_columns = df.select_dtypes(exclude='object').columns
categorical_columns = df.select_dtypes(include='object').columns
print(numerical_columns)
print(categorical_columns)
# Out:
# Index(['Academic_Year', 'CGPA', 'Nervous_Anxiou', 'Worrying',
#        'Trouble_Relaxing', 'Easily_Annoyed', 'Worried_About_Affairs',
#        'Restless', 'Felt_Afraid', 'Anxiety_Value', 'Felt_Upset',
#        'Unable_to_Control', 'Nervous_and_Stressed', 'Unable_to_Cope',
#        'Confident', 'Going_Your_Way', 'Control_Irritations',
#        'On_Top_Performance', 'Angered', 'Piling_Up', 'Stress_Value',
#        'Little_Interest', 'Feeling_Down', 'Trouble_Sleeping',
#        'Tired_or_Little_Energy', 'Poor_Appetite', 'Feeling_Bad',
#        'Trouble_Concentrating', 'Moving_or_Speaking_Too_Slowly',
#        'Hurt_Yourself', 'Depression_Value'],
#       dtype='object')
# Index(['Age', 'Gender', 'University', 'Department', 'Scholarship',
#        'Anxiety_Label', 'Stress_Label', 'Depression_Label'],
#       dtype='object')

# %%
X = df.drop(['Stress_Value', 'Stress_Label', 'Depression_Value', 'Depression_Label', 'Anxiety_Value', 'Anxiety_Label'], axis=1)

for i in df.columns:
    print(i)
    print(df[i].unique())
# Out:
# Age
# ['18-22' '23-26' 'Below 18' '27-30' 'Above 30']
# Gender
# ['Female' 'Male' 'Prefer not to say']
# University
# ['Independent University, Bangladesh (IUB)' 'Daffodil University'
#  'Bangladesh University of Engineering and Technology (BUET)'
#  'BRAC University' 'Dhaka University (DU)' 'North South University (NSU)'
#  'American International University Bangladesh (AIUB)'
#  'Dhaka University of Engineering and Technology (DUET)'
#  'Rajshahi University (RU)' 'Islamic University of Technology (IUT)'
#  'United International University (UIU)'
#  'Patuakhali Science and Technology University'
#  'Rajshahi University of Engineering and Technology (RUET)'
#  'East West University (EWU)' 'Bangladesh Agricultural University (BAU)']
# Department
# ['Engineering' 'Other' 'Environmental and Life Sciences'
#  'Business and Entrepreneurship Studies' 'Biological Sciences']
# Academic_Year
# [ 4.  1.  3.  2. -1.]
# CGPA
# [2. 5. 3. 4. 1. 0.]
# Scholarship
# ['No' 'Yes']
# Nervous_Anxiou
# ...
